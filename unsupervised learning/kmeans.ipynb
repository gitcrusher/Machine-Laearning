# %%
import numpy as np

# %%
class KMeans:
    def __init__(self, k = 3, max_iters = 100):
        self.max_iters = max_iters
        self.centroids = None
        self.clusters = [[] for_ in range(self.k)]
    
    def fit(self,X):
        self.x= X
        random_sample_inices = nprandom.choice(seld.n_sample, self.k, replace = False)
        for _ in range(self.max_iters):
            self.clusters = self._create_clusters(self.centroids)
            centriods.old = self.centroids
            self.centroids = self._get_centroids(slef.clusters)
            if self._is_converged(centriods.old, self.centroids): 
                break

    def _create_clusters(self, centroids):
        clusters= [[] for _ in range(self.k)]

        for idx,sample in enumerate(self.x):
            centroid_idx = self._closest_centroid(sample,centroids)
            clusters[centroid_idx].append(idx)
        return clusters
    
    def _closest_centroid(self, sample, centroids):
        dist=[(np.sqrt(np.sum((sample - centroid) ** 2))) for centroid in centroids]
        return np.argmin(dist)
# Out:
#   Cell In[2], line 5
#     self.clusters = [[] for_ in range(self.k)]
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
