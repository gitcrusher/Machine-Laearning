# %%
from springtime.datasets import PEP725Phenor

# Flowering of Lilac (Syringa vulgaris, phenophase 60 = beginning of flowering)
dataset = PEP725Phenor(
    species="Syringa vulgaris",
    phenophase=60
)

df = dataset.load()
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from springtime.datasets import PEP725Phenor
#       3 # Flowering of Lilac (Syringa vulgaris, phenophase 60 = beginning of flowering)
#       4 dataset = PEP725Phenor(
#       5     species="Syringa vulgaris",
#       6     phenophase=60
#       7 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\springtime\datasets\__init__.py:9
#       6 from pydantic import Field, TypeAdapter
#       7 from typing_extensions import Annotated
# ----> 9 from springtime.datasets.appeears import Appeears
#      10 from springtime.datasets.daymet import Daymet
#      11 from springtime.datasets.eobs import EOBS
#
# ...
