# %%
sample_text = "is this a sample text for testing? <html >, <body> Hello World! </body> </html>"

# %%
import re 
def strip_words(data):
    p = re.compile(r'<.*?>')
    return p.sub('', data)

# %%
strip_words(sample_text)
# Out:
# 'is this a sample text for testing? ,  Hello World!  '
