# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('flower.csv',encoding='latin-1', sep="\t")
pd.set_option('display.max_columns', None)

# %%
df.head(10)
# Out:
#        gbifID                            datasetKey  occurrenceID  kingdom  \
# 0  3997773147  7a3679ef-5582-4aaa-81f0-8c2545cafc81  o-1015119539  Plantae
# 1  3997844095  7a3679ef-5582-4aaa-81f0-8c2545cafc81  o-1015119755  Plantae
# 2  5109413341  7a3679ef-5582-4aaa-81f0-8c2545cafc81  o-1015119836  Plantae
# 3  3997773178  7a3679ef-5582-4aaa-81f0-8c2545cafc81  o-1015124786  Plantae
# 4  5109413364  7a3679ef-5582-4aaa-81f0-8c2545cafc81  o-1015125659  Plantae
# 5  3997844128  7a3679ef-5582-4aaa-81f0-8c2545cafc81  o-1015125893  Plantae
# 6  5109413372  7a3679ef-5582-4aaa-81f0-8c2545cafc81  o-1015126748  Plantae
# 7  3997773194  7a3679ef-5582-4aaa-81f0-8c2545cafc81  o-1015126766  Plantae
# 8  5109413373  7a3679ef-5582-4aaa-81f0-8c2545cafc81  o-1015126946  Plantae
# 9  5109413374  7a3679ef-5582-4aaa-81f0-8c2545cafc81  o-1015127198  Plantae
#
#          phylum          class        order         family           genus  \
# 0  Tracheophyta  Magnoliopsida      Fagales       Fagaceae         Quercus
# 1  Tracheophyta  Magnoliopsida  Celastrales  Parnassiaceae       Parnassia
# 2  Tracheophyta  Magnoliopsida      Rosales       Rosaceae     Cotoneaster
# 3  Tracheophyta  Magnoliopsida     Lamiales      Lamiaceae          Salvia
# 4  Tracheophyta  Magnoliopsida   Sapindales       Rutaceae          Citrus
# 5  Tracheophyta     Liliopsida  Asparagales    Orchidaceae        Arundina
# 6  Tracheophyta  Magnoliopsida     Ericales      Ericaceae  Arctostaphylos
# 7  Tracheophyta  Magnoliopsida    Asterales     Asteraceae    Leontopodium
# 8  Tracheophyta  Magnoliopsida    Asterales     Asteraceae         Sonchus
# 9  Tracheophyta  Magnoliopsida  Gentianales    Apocynaceae    Gomphocarpus
#
#                     species  infraspecificEpithet taxonRank  \
# 0             Quercus suber                   NaN   SPECIES
# 1       Parnassia palustris                   NaN   SPECIES
# 2  Cotoneaster salicifolius                   NaN   SPECIES
# 3        Salvia officinalis                   NaN   SPECIES
# 4            Citrus hystrix                   NaN   SPECIES
# 5     Arundina graminifolia                   NaN   SPECIES
# 6   Arctostaphylos uva-ursi                   NaN   SPECIES
# 7       Leontopodium nivale                   NaN   SPECIES
# 8         Sonchus oleraceus                   NaN   SPECIES
# 9  Gomphocarpus physocarpus                   NaN   SPECIES
#
#                                      scientificName  \
# 0                                  Quercus suber L.
# 1                            Parnassia palustris L.
# 2                  Cotoneaster salicifolius Franch.
# 3                             Salvia officinalis L.
# 4                                Citrus hystrix DC.
# 5              Arundina graminifolia (D.Don) Hochr.
# 6              Arctostaphylos uva-ursi (L.) Spreng.
# 7  Leontopodium nivale (Ten.) A.Huet ex Hand.-Mazz.
# 8                              Sonchus oleraceus L.
# 9                   Gomphocarpus physocarpus E.Mey.
#
#                            verbatimScientificName  \
# 0                                Quercus suber L.
# 1                          Parnassia palustris L.
# 2                Cotoneaster salicifolius Franch.
# 3                           Salvia officinalis L.
# 4                              Citrus hystrix DC.
# 5            Arundina graminifolia (D.Don) Hochr.
# 6            Arctostaphylos uva-ursi (L.) Spreng.
# 7  Leontopodium nivale (Ten.) Huet ex Hand.-Mazz.
# 8                            Sonchus oleraceus L.
# 9                 Gomphocarpus physocarpus E.Mey.
#
#   verbatimScientificNameAuthorship countryCode  locality  stateProvince  \
# 0                               L.          ES       NaN            NaN
# 1                               L.          SI       NaN            NaN
# 2                          Franch.          GB       NaN            NaN
# 3                               L.          US       NaN            NaN
# 4                              DC.          ID       NaN            NaN
# 5                   (D.Don) Hochr.          SG       NaN            NaN
# 6                     (L.) Spreng.          FR       NaN            NaN
# 7       (Ten.) Huet ex Hand.-Mazz.          IT       NaN            NaN
# 8                               L.          NL       NaN            NaN
# 9                           E.Mey.          ES       NaN            NaN
#
#   occurrenceStatus  individualCount                      publishingOrgKey  \
# 0          PRESENT                1  da86174a-a605-43a4-a5e8-53d484152cd3
# 1          PRESENT                1  da86174a-a605-43a4-a5e8-53d484152cd3
# 2          PRESENT                1  da86174a-a605-43a4-a5e8-53d484152cd3
# 3          PRESENT                1  da86174a-a605-43a4-a5e8-53d484152cd3
# 4          PRESENT                1  da86174a-a605-43a4-a5e8-53d484152cd3
# 5          PRESENT                1  da86174a-a605-43a4-a5e8-53d484152cd3
# 6          PRESENT                1  da86174a-a605-43a4-a5e8-53d484152cd3
# 7          PRESENT                1  da86174a-a605-43a4-a5e8-53d484152cd3
# 8          PRESENT                1  da86174a-a605-43a4-a5e8-53d484152cd3
# 9          PRESENT                1  da86174a-a605-43a4-a5e8-53d484152cd3
#
#    decimalLatitude  decimalLongitude  coordinateUncertaintyInMeters  \
# 0        42.808708         -9.107053                            NaN
# 1        46.379817         14.351453                           12.0
# 2        55.876914         -4.264699                           24.0
# 3        47.540318       -122.382225                           35.0
# 4         3.981639         97.345410                            6.0
# 5         1.307079        103.818423                            4.0
# 6        42.799271          1.788327                           15.0
# 7        46.599412         11.763526                            5.0
# 8        52.721069          4.676590                            5.0
# 9        36.395556         -5.656147                            NaN
#
#    coordinatePrecision  elevation  elevationAccuracy  depth  depthAccuracy  \
# 0                  NaN      62.00                0.0    NaN            NaN
# 1                  NaN    1183.61                0.0    NaN            NaN
# 2                  NaN     130.51                0.0    NaN            NaN
# 3                  NaN     127.58                0.0    NaN            NaN
# 4                  NaN     918.80                0.0    NaN            NaN
# 5                  NaN      22.15                0.0    NaN            NaN
# 6                  NaN    1744.59                0.0    NaN            NaN
# 7                  NaN    2274.61                0.0    NaN            NaN
# 8                  NaN       1.82                0.0    NaN            NaN
# 9                  NaN      34.00                0.0    NaN            NaN
#
#                   eventDate  day  month  year  taxonKey  speciesKey  \
# 0      2022-08-18T12:41:19Z   18      8  2022   2879411   2879411.0
# 1      2022-08-18T14:54:06Z   18      8  2022   3032585   3032585.0
# 2      2022-08-18T14:59:20Z   18      8  2022   3026074   3026074.0
# 3  2022-08-18T22:45:07.007Z   18      8  2022   2927004   2927004.0
# 4  2022-08-19T03:41:01.131Z   19      8  2022   6433679   6433679.0
# 5  2022-08-19T05:31:25.376Z   19      8  2022   2795522   2795522.0
# 6  2022-08-19T07:54:39.605Z   19      8  2022   2882580   2882580.0
# 7  2022-08-19T07:56:44.042Z   19      8  2022   3140685   3140685.0
# 8  2022-08-19T08:20:11.638Z   19      8  2022   8228544   8228544.0
# 9      2022-08-18T20:19:19Z   18      8  2022   3170326   3170326.0
#
#        basisOfRecord  institutionCode  collectionCode  catalogNumber  \
# 0  HUMAN_OBSERVATION              NaN             NaN            NaN
# 1  HUMAN_OBSERVATION              NaN             NaN            NaN
# 2  HUMAN_OBSERVATION              NaN             NaN            NaN
# 3  HUMAN_OBSERVATION              NaN             NaN            NaN
# 4  HUMAN_OBSERVATION              NaN             NaN            NaN
# 5  HUMAN_OBSERVATION              NaN             NaN            NaN
# 6  HUMAN_OBSERVATION              NaN             NaN            NaN
# 7  HUMAN_OBSERVATION              NaN             NaN            NaN
# 8  HUMAN_OBSERVATION              NaN             NaN            NaN
# 9  HUMAN_OBSERVATION              NaN             NaN            NaN
#
#    recordNumber  identifiedBy  dateIdentified    license  rightsHolder  \
# 0           NaN           NaN             NaN  CC_BY_4_0           NaN
# 1           NaN           NaN             NaN  CC_BY_4_0           NaN
# 2           NaN           NaN             NaN  CC_BY_4_0           NaN
# 3           NaN           NaN             NaN  CC_BY_4_0           NaN
# 4           NaN           NaN             NaN  CC_BY_4_0           NaN
# 5           NaN           NaN             NaN  CC_BY_4_0           NaN
# 6           NaN           NaN             NaN  CC_BY_4_0           NaN
# 7           NaN           NaN             NaN  CC_BY_4_0           NaN
# 8           NaN           NaN             NaN  CC_BY_4_0           NaN
# 9           NaN           NaN             NaN  CC_BY_4_0           NaN
#
#    recordedBy  typeStatus  establishmentMeans           lastInterpreted  \
# 0         NaN         NaN                 NaN  2025-07-04T16:58:37.681Z
# 1         NaN         NaN                 NaN  2025-07-04T16:58:37.681Z
# 2         NaN         NaN                 NaN  2025-07-04T16:58:37.681Z
# 3         NaN         NaN                 NaN  2025-07-04T16:58:37.681Z
# 4         NaN         NaN                 NaN  2025-07-04T16:58:37.681Z
# 5         NaN         NaN                 NaN  2025-07-04T16:58:37.681Z
# 6         NaN         NaN                 NaN  2025-07-04T16:58:37.681Z
# 7         NaN         NaN                 NaN  2025-07-04T16:58:37.681Z
# 8         NaN         NaN                 NaN  2025-07-04T16:58:37.681Z
# 9         NaN         NaN                 NaN  2025-07-04T16:58:37.681Z
#
#                mediaType                                              issue
# 0  StillImage;StillImage  COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDI...
# 1             StillImage  COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDI...
# 2             StillImage  COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDI...
# 3             StillImage  COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDI...
# 4             StillImage  COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDI...
# 5  StillImage;StillImage  COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDI...
# 6             StillImage  COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDI...
# 7             StillImage  COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDI...
# 8             StillImage  COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDI...
# 9             StillImage  COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDI...

# %%
df['coordinateUncertaintyInMeters'].isnull().sum()
# Out:
# np.int64(805276)

# %%
df['depth'].isnull().sum()
# Out:
# np.int64(2592699)

# %%
df.shape
# Out:
# (2592699, 50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2592699 entries, 0 to 2592698
# Data columns (total 50 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   gbifID                            int64
#  1   datasetKey                        object
#  2   occurrenceID                      object
#  3   kingdom                           object
#  4   phylum                            object
#  5   class                             object
#  6   order                             object
#  7   family                            object
#  8   genus                             object
#  9   species                           object
#  10  infraspecificEpithet              float64
#  11  taxonRank                         object
#  12  scientificName                    object
#  13  verbatimScientificName            object
#  14  verbatimScientificNameAuthorship  object
#  15  countryCode                       object
#  16  locality                          float64
#  17  stateProvince                     float64
#  18  occurrenceStatus                  object
#  19  individualCount                   int64
#  20  publishingOrgKey                  object
#  21  decimalLatitude                   float64
#  22  decimalLongitude                  float64
#  23  coordinateUncertaintyInMeters     float64
#  24  coordinatePrecision               float64
#  25  elevation                         float64
#  26  elevationAccuracy                 float64
#  27  depth                             float64
#  28  depthAccuracy                     float64
#  29  eventDate                         object
#  30  day                               int64
#  31  month                             int64
#  32  year                              int64
#  33  taxonKey                          int64
#  34  speciesKey                        float64
#  35  basisOfRecord                     object
#  36  institutionCode                   float64
#  37  collectionCode                    float64
#  38  catalogNumber                     float64
#  39  recordNumber                      float64
#  40  identifiedBy                      float64
#  41  dateIdentified                    float64
#  42  license                           object
#  43  rightsHolder                      float64
#  44  recordedBy                        float64
#  45  typeStatus                        float64
#  46  establishmentMeans                float64
#  47  lastInterpreted                   object
#  48  mediaType                         object
#  49  issue                             object
# dtypes: float64(22), int64(6), object(22)
# memory usage: 989.0+ MB

# %%
cols = [
'gbifID',
'datasetKey',
'occurrenceID',
'kingdom',

'infraspecificEpithet',
'taxonRank',
'scientificName',

'verbatimScientificNameAuthorship',
'countryCode',
'locality',
'stateProvince',
'occurrenceStatus',
'individualCount',
'publishingOrgKey',
'coordinateUncertaintyInMeters',
'coordinatePrecision',

'elevationAccuracy',
'depth',
'depthAccuracy',
'eventDate',
'day',
'month',
'year',
'taxonKey',
'speciesKey',
'basisOfRecord',
'institutionCode',
'collectionCode',
'catalogNumber',
'recordNumber',
'identifiedBy',
'dateIdentified',
'license',
'rightsHolder',
'recordedBy',
'typeStatus',
'establishmentMeans',
'lastInterpreted',
'mediaType',
'issue'
]
df.drop(columns=cols,axis=1,inplace=True)

# %%
df.head()
# Out:
#          phylum          class        order         family        genus  \
# 0  Tracheophyta  Magnoliopsida      Fagales       Fagaceae      Quercus
# 1  Tracheophyta  Magnoliopsida  Celastrales  Parnassiaceae    Parnassia
# 2  Tracheophyta  Magnoliopsida      Rosales       Rosaceae  Cotoneaster
# 3  Tracheophyta  Magnoliopsida     Lamiales      Lamiaceae       Salvia
# 4  Tracheophyta  Magnoliopsida   Sapindales       Rutaceae       Citrus
#
#                     species            verbatimScientificName  \
# 0             Quercus suber                  Quercus suber L.
# 1       Parnassia palustris            Parnassia palustris L.
# 2  Cotoneaster salicifolius  Cotoneaster salicifolius Franch.
# 3        Salvia officinalis             Salvia officinalis L.
# 4            Citrus hystrix                Citrus hystrix DC.
#
#    decimalLatitude  decimalLongitude  elevation
# 0        42.808708         -9.107053      62.00
# 1        46.379817         14.351453    1183.61
# 2        55.876914         -4.264699     130.51
# 3        47.540318       -122.382225     127.58
# 4         3.981639         97.345410     918.80

# %%
df.rename(columns={'verbatimScientificName': 'scientificName'}, inplace=True)

# %%
df.head()
# Out:
#          phylum          class        order         family        genus  \
# 0  Tracheophyta  Magnoliopsida      Fagales       Fagaceae      Quercus
# 1  Tracheophyta  Magnoliopsida  Celastrales  Parnassiaceae    Parnassia
# 2  Tracheophyta  Magnoliopsida      Rosales       Rosaceae  Cotoneaster
# 3  Tracheophyta  Magnoliopsida     Lamiales      Lamiaceae       Salvia
# 4  Tracheophyta  Magnoliopsida   Sapindales       Rutaceae       Citrus
#
#                     species                    scientificName  \
# 0             Quercus suber                  Quercus suber L.
# 1       Parnassia palustris            Parnassia palustris L.
# 2  Cotoneaster salicifolius  Cotoneaster salicifolius Franch.
# 3        Salvia officinalis             Salvia officinalis L.
# 4            Citrus hystrix                Citrus hystrix DC.
#
#    decimalLatitude  decimalLongitude  elevation
# 0        42.808708         -9.107053      62.00
# 1        46.379817         14.351453    1183.61
# 2        55.876914         -4.264699     130.51
# 3        47.540318       -122.382225     127.58
# 4         3.981639         97.345410     918.80

# %%
df.to_csv
